# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
folder_of_data = "/data001/projects/enserrog/AbigailData/energy_over_time/energy_decomp_model_quality_summary_plot/"

# %%
# !pip3 install matplotlib
# !pip3 install pandas
# !pip3 install h5py
# !pip3 install scipy numba cython multiprocess boost==1.74
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
# ERROR: Could not find a version that satisfies the requirement boost==1.74 (from versions: 0.1)
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0.1
# [notice] To update, run: pip install --upgrade pip
# ERROR: No matching distribution found for boost==1.74

# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np

# %%
from src.util import find_file_recursive
from src.processing import process_session

# %%
all_reach_states = find_file_recursive(folder_of_data, "model_quality_summary.png")
# Out:
# 📁 Searching in: /data001/projects/enserrog/AbigailData/energy_over_time/energy_decomp_model_quality_summary_plot
#   ❌ 'model_quality_summary.png' not found
#   📂 Found 22 subdirectories
#   📁 Searching in: /data001/projects/enserrog/AbigailData/energy_over_time/energy_decomp_model_quality_summary_plot/210421_results
#     ❌ 'model_quality_summary.png' not found
#     📂 Found 1 subdirectories
#     📁 Searching in: /data001/projects/enserrog/AbigailData/energy_over_time/energy_decomp_model_quality_summary_plot/210421_results/210421_rep1
#       ❌ 'model_quality_summary.png' not found
#       📂 Found 1 subdirectories
#       📁 Searching in: /data001/projects/enserrog/AbigailData/energy_over_time/energy_decomp_model_quality_summary_plot/210421_results/210421_rep1/full_reach
#         ✅ Found 'model_quality_summary.png'
#   📁 Searching in: /data001/projects/enserrog/AbigailData/energy_over_time/energy_decomp_model_quality_summary_plot/210422_results
# ...

# %%
import shutil
for rep in all_reach_states:
    rep_id = rep.split("/")[-2]
    id = rep.split("/")[-3][:6]
    shutil.copy(rep, f'./model_quality/{id}_model_quality.png')

# %%
all_reach_states[0].split("/")[-3][:6]
# Out:
# '210421'

# %%
all_reach_states_kin = find_file_recursive(folder_of_data, "energy_kinematics_stim_0.png")
# Out:
# 📁 Searching in: /data001/projects/enserrog/AbigailData/energy_over_time/energy_decomp_model_quality_summary_plot
#   ❌ 'energy_kinematics_stim_0.png' not found
#   📂 Found 22 subdirectories
#   📁 Searching in: /data001/projects/enserrog/AbigailData/energy_over_time/energy_decomp_model_quality_summary_plot/210421_results
#     ❌ 'energy_kinematics_stim_0.png' not found
#     📂 Found 1 subdirectories
#     📁 Searching in: /data001/projects/enserrog/AbigailData/energy_over_time/energy_decomp_model_quality_summary_plot/210421_results/210421_rep1
#       ❌ 'energy_kinematics_stim_0.png' not found
#       📂 Found 1 subdirectories
#       📁 Searching in: /data001/projects/enserrog/AbigailData/energy_over_time/energy_decomp_model_quality_summary_plot/210421_results/210421_rep1/full_reach
#         ✅ Found 'energy_kinematics_stim_0.png'
#         📂 Found 1 subdirectories
# ...

# %%
import shutil
for rep in all_reach_states_kin:
    rep_id = rep.split("/")[-2]
    id = rep.split("/")[-3][:6]
    shutil.copy(rep, f'./model_quality/results/{id}_energy_kinematics_stim_0.png')
