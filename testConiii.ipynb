# %%
# !pip install numpy scipy numba cython multiprocess matplotlib mpmath trash-cli
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Installing build dependencies ... one
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for trash-cli: filename=trash_cli-0.24.5.26-py3-none-any.whl size=104131 sha256=2bc15bd10d4eaa4b3287cb077e4b6236af23fdfedca33ea5b1ead57b3a537f80
#   Stored in directory: /home/ceas/enserrog/.cache/pip/wheels/e8/cf/35/d50146630e5773fe404849118310bf9290a5a8a59ba4d9ebdc
# Successfully built trash-cli
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 26.0
# [notice] To update, run: pip install --upgrade pip

# %%
# !git clone https://github.com/Al-Borno-Lab/coniii.git
# Out:
# Cloning into 'coniii'...
# remote: Enumerating objects: 3707, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 3707 (delta 74), reused 76 (delta 64), pack-reused 3610 (from 2)
# Receiving objects: 100% (3707/3707), 17.64 MiB | 17.49 MiB/s, done.
# Resolving deltas: 100% (2581/2581), done.

# %%
# !apt-get install trash-cli
# Out:
# /bin/bash: apt-get: command not found

# %%
cd coniii
# Out:
# /home/ceas/enserrog/ising_EnergyOverTime/coniii
# /shared/python/python39/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
# !./pypi_compile.sh
# Out:
# trash-cli is not installed. Cannot empty dist directory safely.
# *****************************************************
# Boost not compiled. See above errors for g++ message.
# *****************************************************
# usage: setup.py [global_opts] cmd1 [cmd1_opts] [cmd2 [cmd2_opts] ...]
#    or: setup.py --help [cmd1 cmd2 ...]
#    or: setup.py --help-commands
#    or: setup.py cmd --help
#
# error: invalid command 'bdist_wheel'
# running sdist
# running egg_info
# writing coniii.egg-info/PKG-INFO
# writing dependency_links to coniii.egg-info/dependency_links.txt
# writing requirements to coniii.egg-info/requires.txt
# writing top-level names to coniii.egg-info/top_level.txt
# reading manifest file 'coniii.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# ...
# adding license file 'LICENSE.txt'
# writing manifest file 'coniii.egg-info/SOURCES.txt'
# running check
# creating coniii-3.0.1
# creating coniii-3.0.1/cpp
# creating coniii-3.0.1/coniii
# ...
